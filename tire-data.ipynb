# %% [markdown]
# # FastF1 Notes
# ## Track Status Codes
# 1. Track Clear
# 1. Yellow Flag
# 1. Unknown
# 1. Safety Car
# 1. Red Flag
# 1. VSC Deployed
# 1. VSC Ending
#
# ## Misc
# * SignalRClient should be started 2-3 minutes before session start to collect all live data

# %%
import fastf1 as f1
import fastf1.livetiming.client as LiveClient
import fastf1.livetiming.data as LiveData
import pandas

# %%
# Race data test
session = f1.get_session(2025, "Monaco", "Q") # optional: backend = "fastf1"
session.load(telemetry = False, weather = False)
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '16', '81', '44', '1', '6', '14', '31', '30', '23', '55', '22', '27', '63', '12', '5', '87', '10', '18', '43']

# %%
q = session.laps[["Driver", "Stint", "Compound", "TyreLife", 
                  "IsAccurate", "FastF1Generated"]]

# %%
q.loc[q['Driver'] == "ALO"]
# Out:
#     Driver  Stint Compound  TyreLife  IsAccurate  FastF1Generated
# 159    ALO    1.0     SOFT       1.0       False            False
# 160    ALO    1.0     SOFT       2.0        True            False
# 161    ALO    1.0     SOFT       3.0        True            False
# 162    ALO    1.0     SOFT       4.0        True            False
# 163    ALO    1.0     SOFT       5.0        True            False
# 164    ALO    1.0     SOFT       6.0        True            False
# 165    ALO    1.0     SOFT       7.0       False            False
# 166    ALO    2.0     SOFT       1.0       False            False
# 167    ALO    2.0     SOFT       2.0        True            False
# 168    ALO    2.0     SOFT       3.0        True            False
# 169    ALO    2.0     SOFT       4.0        True            False
# 170    ALO    2.0     SOFT       5.0       False            False
# 171    ALO    3.0     SOFT       1.0       False            False
# 172    ALO    3.0     SOFT       2.0        True            False
# 173    ALO    3.0     SOFT       3.0        True            False
# 174    ALO    3.0     SOFT       4.0       False            False
# 175    ALO    4.0   MEDIUM       2.0       False            False
# 176    ALO    4.0   MEDIUM       3.0        True            False
# 177    ALO    4.0   MEDIUM       4.0        True            False
# 178    ALO    4.0   MEDIUM       5.0        True            False
# 179    ALO    4.0   MEDIUM       6.0        True            False
# 180    ALO    4.0   MEDIUM       7.0       False            False
# 181    ALO    5.0     SOFT       5.0       False            False
# 182    ALO    5.0     SOFT       6.0        True            False
# 183    ALO    5.0     SOFT       7.0        True            False
# 184    ALO    5.0     SOFT       8.0       False            False
# 185    ALO    6.0     SOFT       1.0       False            False
# 186    ALO    6.0     SOFT       2.0        True            False
# 187    ALO    6.0     SOFT       3.0        True            False
# 188    ALO    6.0     SOFT       4.0       False            False
