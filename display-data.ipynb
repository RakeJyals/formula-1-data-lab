# %%
library("tidyverse")
options(repr.plot.width = 20, repr.plot.height = 10)
# Out:
# Warning message:
# “Your system is mis-configured: ‘/var/db/timezone/localtime’ is not a symlink”
# Warning message:
# “‘/var/db/timezone/localtime’ is not identical to any known timezone file”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
data = read.csv("2025-Melbourne-Race.csv") |> arrange(Time) |> mutate()

# %%
#head(data)
#unique(data[,'Driver'])
#data[2, "LapTime"]
    filter(data, Driver == "NOR")
# Out:
#    X   Driver LapNumber Stint LapStartTime Time      LapTime PitOutTime
# 1  593 NOR     1        1      4260.355     4377.726 117.099       NA
# 2  594 NOR     2        1      4377.726     4547.663      NA       NA
# 3  595 NOR     3        2      4547.663     4709.359      NA 4550.143
# 4  596 NOR     4        3      4709.359     4865.355      NA 4711.544
# 5  597 NOR     5        4      4865.355     5009.003 143.648 4867.473
# 6  598 NOR     6        4      5009.003     5149.426 140.423       NA
# 7  599 NOR     7        4      5149.426     5286.534 137.108       NA
# 8  600 NOR     8        4      5286.534     5382.812  96.278       NA
# 9  601 NOR     9        4      5382.812     5477.450  94.638       NA
# 10 602 NOR    10        4      5477.450     5569.580  92.130       NA
# 11 603 NOR    11        4      5569.580     5661.769  92.189       NA
# 12 604 NOR    12        4      5661.769     5753.547  91.778       NA
# ...

# %%
data |> filter(FastF1Generated == "False")
# Todo: Figure out how to interpret pit in/pit out times
# Out:
#     X   Driver LapNumber Stint LapStartTime Time     LapTime PitOutTime
# 1   593 NOR    1         1     4260.355     4377.726 117.099       NA
# 2     0 VER    1         1     4260.355     4380.002 119.392       NA
# 3   813 PIA    1         1     4260.355     4381.467 120.807       NA
# 4   755 RUS    1         1     4260.355     4385.317 124.644       NA
# 5   204 LEC    1         1     4260.355     4389.163 128.480       NA
# 6   318 TSU    1         1     4260.355     4391.264 130.655       NA
# 7   375 ALB    1         1     4260.355     4392.809 132.195       NA
# 8   650 HAM    1         1     4260.355     4393.605 132.883       NA
# 9    57 GAS    1         1     4260.355     4394.728 134.132       NA
# 10  171 ALO    1         1     4260.355     4397.788 137.178       NA
# 11  261 STR    1         1     4260.355     4400.053 139.485       NA
# 12  432 HUL    1         1     4260.355     4401.891 141.221       NA
# ...

# %%
data |>
filter(Driver %in% c("ALO", "PIA", "VER")) |>
#filter(Driver == "ALO") |>
filter(FastF1Generated == "False" & LapTime != "") |>
ggplot(aes(x = Time, y = LapTime, color = Driver, group = interaction(Stint, Driver))) +
    geom_line(linewidth = 1.2, alpha = 0.5)
# Out:
# plot without title

# %%
inaccurate_data_test = data |> select(LapStartTime, Time, LapTime) |> mutate(residual = Time - LapStartTime - LapTime)
innacurate_data_test |> select(residual) |> summary()
# Out:
# Error: object 'innacurate_data_test' not found
# Traceback:
#
# 1. select(innacurate_data_test, residual)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'innacurate_data_test' not found", base::quote(eval(expr,
#  .     envir)))
